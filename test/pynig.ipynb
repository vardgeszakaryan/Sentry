# %%
# !pip install pylabel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pylabel
#   Downloading pylabel-0.1.55-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (2.3.0)
# Collecting bbox-visualizer (from pylabel)
#   Downloading bbox_visualizer-0.3.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: matplotlib in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (3.10.3)
# Requirement already satisfied: opencv-python in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (4.13.0.92)
# Requirement already satisfied: scikit-learn in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (1.7.0)
# Collecting jupyter-bbox-widget (from pylabel)
#   Downloading jupyter_bbox_widget-0.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (6.0.2)
# Requirement already satisfied: tqdm in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pylabel) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from bbox-visualizer->pylabel) (2.4.2)
# Collecting anywidget>=0.9.0 (from jupyter-bbox-widget->pylabel)
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Collecting ipywidgets>=7.6.0 (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel)
#   Downloading psygnal-0.15.1-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.4.6)
# Requirement already satisfied: decorator in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.19.2)
# Requirement already satisfied: matplotlib-inline in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.19.2)
# Requirement already satisfied: stack_data in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from matplotlib->pylabel) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from python-dateutil>=2.7->matplotlib->pylabel) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pandas->pylabel) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from pandas->pylabel) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from scikit-learn->pylabel) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from scikit-learn->pylabel) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from scikit-learn->pylabel) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (3.0.0)
# Requirement already satisfied: pure-eval in C:\Users\kaliv\AppData\Roaming\Python\Python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->jupyter-bbox-widget->pylabel) (0.2.3)
# Downloading pylabel-0.1.55-py3-none-any.whl (27 kB)
# Downloading bbox_visualizer-0.3.0-py3-none-any.whl (10 kB)
# Downloading jupyter_bbox_widget-0.6.0-py3-none-any.whl (24 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/914.9 kB 275.1 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/914.9 kB 275.1 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/914.9 kB 275.1 kB/s eta 0:00:02
#    --------------------- ---------------- 524.3/914.9 kB 275.1 kB/s eta 0:00:02
#    -------------------------------- ----- 786.4/914.9 kB 302.2 kB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 321.2 kB/s  0:00:03
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 524.3 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.2 MB 524.3 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.2 MB 524.3 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 541.1 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.2 MB 578.3 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 578.3 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 599.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 599.2 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 616.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 616.8 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 637.0 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 652.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 651.5 kB/s  0:00:03
# Downloading psygnal-0.15.1-cp311-cp311-win_amd64.whl (415 kB)
# Installing collected packages: widgetsnbextension, psygnal, jupyterlab_widgets, bbox-visualizer, ipywidgets, anywidget, jupyter-bbox-widget, pylabel
#
#    ---------------------------------------- 0/8 [widgetsnbextension]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ----- ---------------------------------- 1/8 [psygnal]
#    ---------- ----------------------------- 2/8 [jupyterlab_widgets]
#    --------------- ------------------------ 3/8 [bbox-visualizer]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    -------------------- ------------------- 4/8 [ipywidgets]
#    ------------------------- -------------- 5/8 [anywidget]
#    ------------------------- -------------- 5/8 [anywidget]
#    ------------------------- -------------- 5/8 [anywidget]
#    ------------------------------ --------- 6/8 [jupyter-bbox-widget]
#    ----------------------------------- ---- 7/8 [pylabel]
#    ----------------------------------- ---- 7/8 [pylabel]
#    ----------------------------------- ---- 7/8 [pylabel]
#    ----------------------------------- ---- 7/8 [pylabel]
#    ---------------------------------------- 8/8 [pylabel]
#
# Successfully installed anywidget-0.9.21 bbox-visualizer-0.3.0 ipywidgets-8.1.8 jupyter-bbox-widget-0.6.0 jupyterlab_widgets-3.0.16 psygnal-0.15.1 pylabel-0.1.55 widgetsnbextension-4.0.15

# %%
import os
import urllib.request
import zipfile
from pathlib import Path

# 1. Setup raw data directory
raw_dir = Path("data/raw")
raw_dir.mkdir(parents=True, exist_ok=True)

# 2. Download and unpack two datasets (~136 images total)
datasets = {
    "coco8": "https://github.com/ultralytics/yolov5/releases/download/v1.0/coco8.zip",
    "coco128": "https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip",
}

for name, url in datasets.items():
    zip_path = raw_dir / f"{name}.zip"
    extracted_path = raw_dir / name
    
    if not extracted_path.exists():
        print(f"Downloading {name}...")
        urllib.request.urlretrieve(url, zip_path)
        print(f"Extracting {name}...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(raw_dir)
        print(f"{name} ready.\n")
    else:
        print(f"{name} already exists.\n")
# Out:
# Downloading coco8...
# Extracting coco8...
# coco8 ready.

# %%
import pylabel

dataset = pylabel.importer.ImportYoloV5(
    raw_dir
